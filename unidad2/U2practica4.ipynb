# %% [markdown]
# <a href="https://colab.research.google.com/github/carlosmarrufo2e25-cloud/probabilidad/blob/main/unidad2/U2practica4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math as mt
from itertools import combinations
from itertools import combinations_with_replacement
import numpy as np
import itertools


# Permutaciones
nombres=["a", "b", "c", "d", "e", "f", "g"]
n=len(nombres)
r=3  # ¿cómo agrupar?

Pr=mt.factorial(n)/(mt.factorial(n - r))

print("Existen ", Pr, " posibles permutaciones sin repetición del total de ",
      n, " nombres ", " en grupos de ", r, " en ", r)

print("Aquí las permutaciones")
permutaciones_nombres = list(itertools.permutations(nombres, r))

# Imprime las permutaciones
for permutacion in permutaciones_nombres:
    print(permutacion)
