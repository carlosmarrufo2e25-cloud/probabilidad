# %% [markdown]
# <a href="https://colab.research.google.com/github/carlosmarrufo2e25-cloud/probabilidad/blob/main/Unidad_4/practica4_U4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy.stats import binom

# Parámetros de la distribución binomial
n = 10
p = 0.10
x = 2

# Calcular la probabilidad de la variable aleatoria X = 2
probabilidad_x_2 = binom.pmf(x, n, p)

print("La probabilidad de que la variable aleatoria X sea igual a 2 es:", probabilidad_x_2)
