# %% [markdown]
# <a href="https://colab.research.google.com/github/carlosmarrufo2e25-cloud/probabilidad/blob/main/Unidad_4/practica1_U4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Generar datos para la distribución normal

media = 70  # Media
desv_std = 4  # Desviación estándar
num_datos = 500

# generamos los datos de manera aleatoria y los ponemos en una lista (array)
datos = np.random.normal(media, desv_std, num_datos)
datos[0:50]  # Mostrar los primeros 50
# Out:
# array([66.63935013, 74.02388122, 71.56070056, 72.01561429, 66.94030933,
#        72.53980404, 70.41584501, 75.57313667, 70.0313502 , 75.20269071,
#        66.88197917, 71.40261355, 73.52950041, 58.74806376, 73.66657882,
#        66.28831417, 67.12594911, 79.16891922, 73.84560852, 68.93725895,
#        77.47722382, 73.69977718, 67.49600966, 66.10046368, 67.73200243,
#        70.55620705, 75.71858895, 71.05832193, 74.91693966, 74.58486452,
#        66.50521109, 69.12241649, 73.17304812, 73.28161115, 73.405135  ,
#        80.38209746, 77.69379132, 70.18039064, 70.87776927, 70.47115864,
#        68.17313439, 64.75008529, 72.42408826, 73.17206406, 72.73224052,
#        72.60363682, 62.74163884, 66.31780034, 64.91912115, 65.27612491])

# %%
# Graficar histograma
plt.figure(figsize=(6, 4))
plt.hist(datos, bins=15, alpha=0.4, color='b')  # Histograma de los datos
plt.title('Distribución Normal')
plt.xlabel('Peso en kg de los estudiantes')
plt.grid(True)
plt.show()

# %%
import numpy as np
from scipy.stats import norm

# Generar un rango de valores para x
x = np.linspace(media - 4 * desv_std, media + 4 * desv_std, 100)

# Calcular la función de densidad de probabilidad (PDF)
pdf = norm.pdf(x, media, desv_std)

# Visualizar la PDF
plt.figure(figsize=(6, 4))
plt.plot(x, pdf, label='Normal:(media:{}; ds:{})'.format(np.round(media, 2), np.round(desv_std, 2)))
plt.title('Función de Densidad de Probabilidad (PDF) - Distribución Normal')
plt.xlabel('Pesos en Kg. de los estudiantes')
plt.ylabel('Densidad de Probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Graficar histograma
plt.figure(figsize=(6, 4))
plt.hist(datos, bins=15, alpha=0.4, density=True, color='b')
plt.plot( x, pdf, 'k', linewidth=2, )

plt.title('Distribución Normal ')
plt.xlabel('Peso en kg de los estudiantes')
plt.grid(True)
plt.show()
