# %% [markdown]
# <a href="https://colab.research.google.com/github/carlosmarrufo2e25-cloud/probabilidad/blob/main/practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #probabilidad y estadistica
# ## Unidad 1
# ### Facilitador: Jose Gabriel Rodrigez Rivas
# ### Alumno:______
# ### **programa 1: Estadisticas basica e histogramas**

# %%
from statistics import *

# %%
# lista de calificaciones del grupo a de probabilidad y estadistica
grupoa = [70,70,65,90,100,95,45,80,73,20,100,96]
print(grupoa)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]

# %%
# sacar la media de las calificaciones con la formula
promedio = sum(grupoa) / len(grupoa)
print(promedio)
# Out:
# 75.33333333333333

# %%
#determinar el valor de la media con la funcion median
mediana = median(grupoa)
print(mediana)
# Out:
# 76.5

# %%
# determinar la moda
moda = mode(grupoa)
print(moda)
# Out:
# 70

# %%
#determinar la multimoda
moda2 = multimode(grupoa)
print(moda2)
# Out:
# [70, 100]

# %%
#definir una variable de 10 alumnos que recorrieron 100mts
tiempos100mts = [15.6,26.8,48.26,53.7,19.4,50.50,90.5,60.2,70.4,50.25]

# %%
print("El tiempo promedio de los corredores es =>", mean(tiempos100mts) )
print("La mediana de los corredores es =>", median(tiempos100mts) )
print("la moda de los corredores es =>", mode(tiempos100mts) )
# Out:
# El tiempo promedio de los corredores es => 48.561
# La mediana de los corredores es => 50.375
# la moda de los corredores es => 15.6

# %%
#para crear numeros random
import random

# %%
#fabrica 1
fabrica1 =[]
for i in range(100):
  numero_aleatoria= round(random.uniform(50,100), 2)
  fabrica1.append(numero_aleatoria)
print(fabrica1)
# Out:
# [93.23, 51.08, 74.83, 92.98, 57.19, 93.9, 92.17, 61.12, 60.65, 81.94, 53.47, 78.57, 53.58, 81.2, 95.67, 96.85, 68.22, 59.49, 60.09, 83.65, 69.5, 53.81, 89.14, 80.65, 60.57, 83.89, 77.25, 56.25, 71.31, 54.87, 83.04, 86.45, 88.56, 63.16, 51.55, 83.11, 76.78, 68.8, 58.17, 76.3, 63.7, 59.23, 89.36, 91.0, 61.18, 55.04, 73.2, 59.54, 99.53, 91.92, 64.87, 77.63, 82.65, 79.17, 88.86, 71.55, 98.37, 53.76, 70.25, 56.58, 90.05, 51.03, 78.68, 84.32, 83.28, 77.65, 97.92, 82.42, 84.85, 92.71, 62.32, 76.98, 83.04, 78.58, 76.53, 99.12, 72.07, 95.17, 74.22, 81.3, 65.46, 88.19, 91.01, 62.31, 91.37, 59.12, 77.88, 52.6, 61.1, 52.46, 98.55, 98.28, 90.64, 58.3, 56.58, 91.65, 90.17, 54.96, 77.22, 53.09]

# %%
#fabrica 2
fabrica2 =[]
for i in range(100):
  numero_aleatorio= round(random.uniform(70,100), 2)
  fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [78.49, 97.21, 90.0, 96.75, 73.36, 91.6, 78.88, 86.17, 78.44, 93.07, 76.2, 98.94, 75.43, 81.55, 86.11, 89.39, 92.0, 79.07, 98.4, 77.11, 88.98, 95.85, 88.3, 88.89, 99.57, 91.44, 79.06, 84.8, 78.12, 84.53, 74.83, 94.48, 83.94, 75.2, 95.48, 95.4, 89.4, 96.7, 72.49, 82.83, 79.07, 93.63, 90.34, 71.82, 93.72, 71.25, 74.36, 86.89, 80.11, 78.41, 92.03, 99.97, 76.69, 82.52, 83.36, 76.74, 70.29, 85.51, 88.05, 82.23, 93.8, 84.93, 98.97, 90.28, 85.8, 93.32, 77.65, 94.28, 71.95, 98.36, 78.99, 98.58, 73.19, 94.32, 85.48, 88.2, 72.34, 95.15, 83.3, 91.73, 99.34, 71.83, 74.88, 94.61, 81.6, 79.94, 86.45, 99.95, 82.84, 86.06, 98.17, 87.04, 70.97, 97.25, 73.7, 94.58, 77.27, 75.04, 78.5, 78.98]

# %%
# libreria de python para graficar valores
import matplotlib.pyplot as plt

# %%
#imprimir grafica 1
plt.hist(fabrica1)
plt.title("produccion diaria de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'produccion diaria de la fabrica 1')

# %%
#imprimir grafica 2
plt.hist(fabrica2)
plt.title("produccion diaria de la fabrica 2")
# Out:
# Text(0.5, 1.0, 'produccion diaria de la fabrica 2')

# %%
print("valores de la fabrica 1 ")
print("los valores de la fabrica 1 es =>", mean(fabrica1) )
print("la moda de la fabrica 1 es =>", mode(fabrica1) )
print("la media de la fabrica 1 es =>", median(fabrica1) )
# Out:
# valores de la fabrica 1
# los valores de la fabrica 1 es => 75.0361
# la moda de la fabrica 1 es => 83.04
# la media de la fabrica 1 es => 77.235

# %%
print("valores de la fabrica 2 ")
print("los valores de la fabrica 2 es =>", mean(fabrica2) )
print("la moda de la fabrica 2 es =>", mode(fabrica2) )
print("la media de la fabrica 2 es =>", median(fabrica2) )
# Out:
# valores de la fabrica 2
# los valores de la fabrica 2 es => 85.5507
# la moda de la fabrica 2 es => 79.07
# la media de la fabrica 2 es => 85.655

# %%
fig,(ax1, ax2) =plt.subplots(nrows =1, ncols=2, figsize=(10,5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()
