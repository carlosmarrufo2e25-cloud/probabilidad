# %% [markdown]
# <a href="https://colab.research.google.com/github/carlosmarrufo2e25-cloud/probabilidad/blob/main/unidad1/practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from statistics import *

# %%
# lista de calificaciones del grupo a de probabilidad y estadistica
grupoa = [70,70,65,90,100,95,45,80,73,20,100,96]
print(grupoa)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]

# %%
promedio = sum(grupoa) / len(grupoa)
print(promedio)
# Out:
# 75.33333333333333

# %%
mediana = median(grupoa)
print(mediana)
# Out:
# 76.5

# %%
moda = mode(grupoa)
print(moda)
# Out:
# 70

# %%
moda2 = multimode(grupoa)
print(moda2)
# Out:
# [70, 100]

# %%
tiempos100mts = [15.6,26.8,48.26,53.7,19.4,50.50,90.5,60.2,70.4,50.25]

# %%
print("El tiempo promedio de los corredores es =>", mean(tiempos100mts) )
print("La mediana de los corredores es =>", median(tiempos100mts) )
print("la moda de los corredores es =>", mode(tiempos100mts) )
# Out:
# El tiempo promedio de los corredores es => 48.561
# La mediana de los corredores es => 50.375
# la moda de los corredores es => 15.6

# %%
import random

# %%
fabrica1 =[]
for i in range(100):
  numero_aleatoria= round(random.uniform(50,100), 2)
  fabrica1.append(numero_aleatoria)
print(fabrica1)
# Out:
# [60.84, 74.44, 59.4, 65.03, 76.32, 65.5, 69.04, 51.59, 67.88, 68.9, 86.65, 56.63, 62.23, 50.17, 79.28, 67.52, 68.39, 87.81, 51.49, 60.56, 97.76, 58.52, 78.01, 80.01, 94.76, 54.53, 66.24, 68.31, 83.49, 88.23, 88.06, 92.79, 94.35, 62.42, 51.26, 85.83, 60.02, 74.24, 71.56, 95.82, 77.54, 52.07, 56.39, 56.55, 68.79, 50.84, 54.99, 60.94, 72.05, 93.46, 91.47, 60.27, 91.02, 63.27, 65.72, 62.59, 56.23, 75.59, 91.63, 88.78, 91.52, 63.79, 87.94, 59.34, 79.11, 61.11, 54.2, 71.25, 66.94, 70.98, 63.71, 71.66, 73.78, 55.02, 57.27, 58.04, 78.78, 64.7, 79.78, 63.68, 65.94, 85.14, 60.7, 63.71, 86.7, 60.03, 89.75, 81.98, 88.82, 65.88, 73.81, 59.66, 53.88, 74.06, 60.93, 54.77, 98.09, 52.61, 87.15, 75.11]

# %%
fabrica2 =[]
for i in range(100):
  numero_aleatorio= round(random.uniform(70,100), 2)
  fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [94.92, 96.92, 98.26, 92.74, 75.41, 93.71, 89.83, 92.84, 88.02, 83.3, 92.83, 88.27, 73.53, 75.59, 73.67, 86.5, 77.26, 89.67, 98.48, 71.08, 73.84, 99.04, 87.75, 83.95, 80.37, 77.81, 84.32, 79.91, 81.24, 97.31, 95.93, 95.61, 92.51, 70.66, 85.64, 81.91, 89.25, 86.44, 76.96, 74.9, 97.68, 72.62, 96.86, 74.36, 85.32, 98.55, 72.1, 91.03, 84.35, 70.13, 72.79, 82.59, 98.59, 80.46, 70.35, 74.68, 86.52, 90.52, 74.14, 77.25, 92.55, 75.06, 82.1, 96.12, 82.03, 80.57, 96.4, 81.92, 91.99, 91.52, 92.92, 83.96, 71.93, 77.73, 93.95, 95.01, 78.66, 72.79, 96.95, 83.11, 70.83, 80.86, 80.91, 88.55, 93.32, 88.66, 71.82, 92.3, 81.2, 74.52, 77.4, 98.61, 76.77, 98.82, 97.02, 97.83, 73.15, 88.94, 80.21, 87.26]

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(fabrica1)
plt.title("produccion diaria de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'produccion diaria de la fabrica 1')

# %%
plt.hist(fabrica2)
plt.title("produccion diaria de la fabrica 2")
# Out:
# Text(0.5, 1.0, 'produccion diaria de la fabrica 2')

# %%
print("valores de la fabrica 1 ")
print("los valores de la fabrica 1 es =>", mean(fabrica1) )
print("la moda de la fabrica 1 es =>", mode(fabrica1) )
print("la media de la fabrica 1 es =>", median(fabrica1) )
# Out:
# valores de la fabrica 1
# los valores de la fabrica 1 es => 70.7739
# la moda de la fabrica 1 es => 63.71
# la media de la fabrica 1 es => 68.095

# %%
print("valores de la fabrica 2 ")
print("los valores de la fabrica 2 es =>", mean(fabrica2) )
print("la moda de la fabrica 2 es =>", mode(fabrica2) )
print("la media de la fabrica 2 es =>", median(fabrica2) )
# Out:
# valores de la fabrica 2
# los valores de la fabrica 2 es => 84.9532
# la moda de la fabrica 2 es => 72.79
# la media de la fabrica 2 es => 84.335

# %%
fig,(ax1, ax2) =plt.subplots(nrows =1, ncols=2, figsize=(10,5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()
