# %% [markdown]
# <a href="https://colab.research.google.com/github/carlosmarrufo2e25-cloud/probabilidad/blob/main/unidad3/U3practica4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# Valores de la variable aleatoria
x = [5, 6, 7, 8, 9, 10]

# Probabilidades
p = [0.05, 0.10, 0.20, 0.30, 0.25, 0.10]

# Verificar que la suma de probabilidades sea 1
print("Suma de probabilidades:", sum(p))

# Graficar la distribución de probabilidad
plt.stem(x, p)
plt.title("Distribución de Probabilidad")
plt.xlabel("Calificación")
plt.ylabel("Probabilidad")
plt.grid(True)
plt.show()
