# %% [markdown]
# <a href="https://colab.research.google.com/github/carlosmarrufo2e25-cloud/probabilidad/blob/main/unidad3/U3practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Valores posibles de la variable aleatoria
x = [5, 6, 7, 8, 9, 10]

# Probabilidades correspondientes
p = [0.05, 0.10, 0.20, 0.30, 0.25, 0.10]

# Inicializar el valor esperado
valor_esperado = 0

# Recorrer los valores y probabilidades
for i in range(len(x)):
    xi = x[i]        # valor actual
    pi = p[i]        # probabilidad correspondiente
    producto = xi * pi

    valor_esperado += producto

    # Mostrar cada paso
    print(f"x = {xi}, p = {pi}, x*p = {producto:.2f}")

# Mostrar resultado final
print(f"\nValor esperado (Esperanza): {valor_esperado:.2f}")
# Out:
# x = 5, p = 0.05, x*p = 0.25
# x = 6, p = 0.1, x*p = 0.60
# x = 7, p = 0.2, x*p = 1.40
# x = 8, p = 0.3, x*p = 2.40
# x = 9, p = 0.25, x*p = 2.25
# x = 10, p = 0.1, x*p = 1.00
#
# Valor esperado (Esperanza): 7.90
