# %% [markdown]
# <a href="https://colab.research.google.com/github/carlosmarrufo2e25-cloud/probabilidad/blob/main/practica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #probabilidad y estadistica
# ## Unidad 1
# ### Facilitador: Jose Gabriel Rodrigez Rivas
# ### Alumno:______
# ### **programa 1: Estadisticas basica e histogramas**

# %%
from statistics import *
import matplotlib.pyplot as plt
import random

# %%
#fabrica 1
fabrica1 =[]
for i in range(100):
  numero_aleatoria= round(random.uniform(50,100), 2)
  fabrica1.append(numero_aleatoria)
print(fabrica1)
# Out:
# [83.02, 73.16, 66.73, 91.44, 60.31, 74.74, 84.81, 74.41, 79.86, 81.85, 63.15, 88.94, 62.83, 91.96, 68.33, 95.7, 92.22, 74.97, 87.47, 59.89, 55.23, 79.9, 88.49, 58.79, 78.17, 80.51, 73.61, 67.59, 96.59, 95.23, 63.22, 54.52, 78.61, 63.51, 88.7, 67.53, 80.7, 95.67, 96.77, 52.01, 70.59, 59.7, 54.88, 57.66, 68.51, 52.1, 70.42, 75.64, 83.04, 69.65, 58.11, 80.24, 85.95, 57.22, 85.78, 56.14, 97.8, 89.13, 76.6, 97.3, 90.26, 52.42, 89.93, 64.43, 68.99, 99.54, 72.18, 91.8, 96.72, 77.92, 81.11, 85.88, 79.14, 69.85, 77.82, 61.91, 79.19, 78.61, 79.9, 58.21, 54.98, 92.44, 99.39, 81.3, 83.25, 50.12, 53.15, 68.6, 95.57, 95.94, 55.78, 57.1, 71.57, 64.29, 87.52, 73.52, 78.52, 51.52, 94.24, 59.89]

# %%
#fabrica 1
fabrica2 =[]
for i in range(100):
  numero_aleatoria= round(random.uniform(50,100), 2)
  fabrica2.append(numero_aleatoria)
print(fabrica2)
# Out:
# [97.57, 65.27, 69.87, 60.75, 59.2, 53.44, 63.78, 92.07, 71.22, 93.09, 64.72, 86.04, 79.6, 95.6, 70.87, 87.23, 67.32, 59.19, 54.47, 66.71, 96.09, 59.92, 69.13, 76.93, 68.22, 62.98, 57.83, 75.51, 68.5, 85.74, 52.72, 66.4, 87.34, 54.2, 58.52, 92.64, 69.13, 77.78, 85.35, 71.16, 71.49, 84.96, 91.28, 69.55, 83.15, 62.75, 60.7, 87.69, 87.79, 76.16, 72.82, 52.03, 60.46, 93.83, 69.9, 95.32, 75.91, 62.88, 81.83, 87.8, 89.27, 96.74, 64.43, 86.57, 99.13, 94.42, 59.89, 53.41, 93.95, 73.43, 85.25, 86.79, 61.9, 54.35, 58.37, 83.72, 82.15, 67.3, 67.71, 52.91, 92.96, 73.02, 99.54, 84.45, 63.49, 53.81, 61.3, 93.27, 79.13, 96.48, 68.15, 69.6, 99.44, 91.89, 63.01, 84.28, 95.14, 71.11, 76.69, 76.08]

# %%
maximo1 = max(fabrica1)
minimo1 = max(fabrica2)
rango1 = maximo1 - minimo1
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)
desviacion_estandar_fabrica1 =stdev(fabrica1)
print("estadistica descriptiva de la fabrica 1 \n", "media =",media1, "\n mediana= ", mediana1, "\n moda =", moda1, "\n maximo =", maximo1, "\n minimo =", minimo1, "\n rango =", rango1)
print(desviacion_estandar_fabrica1)
# Out:
# estadistica descriptiva de la fabrica 1
#  media = 75.421
#  mediana=  77.21
#  moda = 59.89
#  maximo = 99.54
#  minimo = 99.54
#  rango = 0.0
# 14.128632687424554

# %%
maximo1 = max(fabrica1)
minimo2 = max(fabrica2)
rango2 = maximo1 - minimo2
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)
desviacion_estandar_fabrica2 =stdev(fabrica1)
print("estadistica descriptiva de la fabrica 1 \n", "media =",media2, "\n mediana= ", mediana2, "\n moda =", moda2, "\n maximo =", maximo1, "\n minimo =", minimo2, "\n rango =", rango2)
print(desviacion_estandar_fabrica2)
# Out:
# estadistica descriptiva de la fabrica 1
#  media = 75.2693
#  mediana=  72.91999999999999
#  moda = 69.13
#  maximo = 99.54
#  minimo = 99.54
#  rango = 0.0
# 14.128632687424554
