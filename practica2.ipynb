# %% [markdown]
# <a href="https://colab.research.google.com/github/carlosmarrufo2e25-cloud/probabilidad/blob/main/practica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #probabilidad y estadistica
# ## Unidad 1
# ### Facilitador: Jose Gabriel Rodrigez Rivas
# ### Alumno:______
# ### **programa 1: Estadisticas basica e histogramas**

# %%
from statistics import *
import matplotlib.pyplot as plt
import random

# %%
#fabrica 1
fabrica1 =[]
for i in range(100):
  numero_aleatoria= round(random.uniform(50,100), 2)
  fabrica1.append(numero_aleatoria)
print(fabrica1)
# Out:
# [80.03, 55.45, 66.41, 59.14, 77.09, 68.76, 95.86, 56.63, 82.7, 53.33, 78.67, 82.19, 73.36, 80.39, 81.18, 59.27, 51.36, 58.18, 63.15, 63.16, 87.65, 89.93, 96.95, 74.97, 61.65, 50.77, 68.73, 93.18, 60.57, 54.64, 57.47, 61.42, 76.94, 83.54, 94.46, 96.69, 76.81, 69.69, 69.26, 99.46, 75.44, 85.7, 73.77, 72.19, 65.1, 65.01, 63.05, 78.46, 62.5, 73.68, 59.81, 54.01, 79.12, 91.42, 84.14, 83.09, 80.12, 90.51, 76.9, 94.47, 68.03, 78.61, 76.11, 79.29, 89.08, 70.03, 51.75, 68.61, 99.33, 70.12, 85.81, 65.38, 96.68, 90.93, 55.87, 98.95, 94.3, 54.7, 78.12, 97.15, 79.72, 69.7, 84.39, 79.86, 90.39, 64.5, 99.34, 72.9, 87.63, 95.55, 57.01, 62.89, 54.42, 64.37, 62.37, 56.66, 52.89, 58.45, 74.9, 82.94]

# %%
#fabrica 1
fabrica2 =[]
for i in range(100):
  numero_aleatoria= round(random.uniform(50,100), 2)
  fabrica2.append(numero_aleatoria)
print(fabrica2)
# Out:
# [92.34, 70.13, 77.84, 54.69, 81.27, 94.3, 66.86, 77.25, 71.03, 93.33, 97.15, 93.89, 97.17, 76.02, 77.25, 65.89, 88.29, 58.56, 83.39, 76.59, 70.33, 78.16, 66.07, 50.52, 59.59, 50.66, 90.16, 78.96, 60.98, 92.0, 57.47, 50.61, 65.14, 81.21, 85.37, 71.98, 68.44, 75.78, 89.99, 58.38, 79.39, 99.41, 72.77, 67.17, 88.77, 54.27, 69.56, 67.13, 91.46, 82.06, 58.48, 54.71, 90.73, 71.92, 57.53, 86.55, 92.04, 71.1, 71.29, 88.41, 62.58, 71.67, 72.46, 50.54, 62.31, 61.65, 80.35, 55.93, 60.78, 59.54, 91.88, 99.98, 51.97, 78.49, 78.52, 78.77, 73.88, 86.85, 52.69, 83.37, 59.24, 74.88, 74.22, 80.47, 95.85, 57.75, 83.69, 50.63, 95.06, 51.07, 99.15, 56.65, 73.11, 61.19, 66.58, 91.96, 84.28, 61.35, 84.08, 79.49]

# %%
maximo1 = max(fabrica1)
minimo1 = max(fabrica2)
rango1 = maximo1 - minimo1
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)
desviacion_estandar_fabrica1 =stdev(fabrica1)
print("estadistica descriptiva de la fabrica 1 \n", "media =",media1, "\n mediana= ", mediana1, "\n moda =", moda1, "\n maximo =", maximo1, "\n minimo =", minimo1, "\n rango =", rango1)
print(desviacion_estandar_fabrica1)
# Out:
# estadistica descriptiva de la fabrica 1
#  media = 74.3931
#  mediana=  74.935
#  moda = 80.03
#  maximo = 99.46
#  minimo = 99.98
#  rango = -0.5200000000000102
# 13.967885366298674

# %%
maximo1 = max(fabrica1)
minimo2 = max(fabrica2)
rango2 = maximo1 - minimo2
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)
desviacion_estandar_fabrica2 =stdev(fabrica1)
print("estadistica descriptiva de la fabrica 2 \n", "media =",media2, "\n mediana= ", mediana2, "\n moda =", moda2, "\n maximo =", maximo1, "\n minimo =", minimo2, "\n rango =", rango2)
print(desviacion_estandar_fabrica2)
# Out:
# estadistica descriptiva de la fabrica 2
#  media = 74.047
#  mediana=  74.05
#  moda = 77.25
#  maximo = 99.46
#  minimo = 99.98
#  rango = -0.5200000000000102
# 13.967885366298674

# %%
plt.figure(figsize=(8,6))
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label=f'media={media1:.2f}')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label=f'mediana={mediana1:.2f}')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label=f'moda={moda1:.2f}')
plt.axvline(media1 - desviacion_estandar_fabrica1, color='black', linestyle='dashed', linewidth=2, label=f'desv. Estandar ={desviacion_estandar_fabrica1:.2f}')
plt.axvline(media1 + desviacion_estandar_fabrica1, color='black', linestyle='dashed', linewidth=2)

plt.xlabel('Valor')
plt.ylabel('Frecuancia')
plt.title("produccion diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label=f'media={media2:.2f}')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label=f'mediana={mediana2:.2f}')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label=f'moda={moda2:.2f}')
plt.axvline(media2 - desviacion_estandar_fabrica2, color='black', linestyle='dashed', linewidth=2, label=f'desv. Estandar ={desviacion_estandar_fabrica2:.2f}')
plt.axvline(media2 + desviacion_estandar_fabrica2, color='black', linestyle='dashed', linewidth=2)

plt.xlabel('Valor')
plt.ylabel('Frecuancia')
plt.title("produccion diaria de la fabrica 2")
plt.legend()
plt.show()

# %%
import seaborn as sns

# %%
sns.histplot( x = fabrica1, kde = True, kde_kws = {'bw_adjust':0.5}, bins = 10)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot( x = fabrica2, kde = True, kde_kws = {'bw_adjust':0.5}, bins = 10)
# Out:
# <Axes: ylabel='Count'>
